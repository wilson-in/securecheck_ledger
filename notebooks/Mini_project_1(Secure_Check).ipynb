# %% [markdown]
# <a href="https://colab.research.google.com/github/Infant-Joshva/Mini-Project-1-Secure-Check-/blob/main/notebooks/Mini_project_1(Secure_Check).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project(Secure Check) Initialation and Data Cleaning

# %% [markdown]
# #### Importing Necessary Packages

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
sheet_id= '16qEUKckLFy7j1qoSd1bSQURn9QXDb6ffSBAWzRkPsSg'
sheet_name = "sheet1"

#https://docs.google.com/spreadsheets/d/16qEUKckLFy7j1qoSd1bSQURn9QXDb6ffSBAWzRkPsSg/edit?gid=1282651194#gid=1282651194

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

traffic_df=pd.read_csv(url)
# Out:
# /tmp/ipython-input-5-3468746139.py:8: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   traffic_df=pd.read_csv(url)

# %%
traffic_df.head(10)
# Out:
#    stop_date      stop_date_time country_name driver_gender  driver_age_raw  \
# 0 2020-01-01 2020-01-01 00:00:00       Canada             M              59
# 1 2020-01-01 2020-01-01 00:01:00        India             M              35
# 2 2020-01-01 2020-01-01 00:02:00          USA             M              26
# 3 2020-01-01 2020-01-01 00:03:00       Canada             M              26
# 4 2020-01-01 2020-01-01 00:04:00       Canada             M              62
# 5 2020-01-01 2020-01-01 00:05:00       Canada             F              44
# 6 2020-01-01 2020-01-01 00:06:00          USA             F              80
# 7 2020-01-01 2020-01-01 00:07:00        India             M              72
# 8 2020-01-01 2020-01-01 00:08:00          USA             F              80
# 9 2020-01-01 2020-01-01 00:09:00          USA             M              43
#
#   driver_race     violation_raw  search_conducted     search_type  \
# 0       Asian     Drunk Driving              True  Vehicle Search
# 1       Other             Other             False  Vehicle Search
# 2       Black  Signal Violation             False           Frisk
# 3       Black          Speeding              True           Frisk
# 4       Other          Speeding             False  Vehicle Search
# 5       Other     Drunk Driving              True  Vehicle Search
# 6       White  Signal Violation             False  Vehicle Search
# 7       Asian     Drunk Driving             False            None
# 8    Hispanic             Other              True           Frisk
# 9       Asian  Signal Violation              True            None
#
#   stop_outcome  is_arrested stop_duration  drugs_related_stop vehicle_number  \
# 0       Ticket         True         16-30                True     UP76DY3473
# 1       Arrest         True         16-30                True     RJ83PZ4441
# 2       Ticket         True         16-30                True     RJ32OM7264
# 3      Warning        False          0-15                True     RJ76TI3807
# 4       Arrest         True         16-30               False     WB63BB8305
# 5       Ticket        False         16-30               False     MH89ZF7676
# 6       Ticket        False           30+               False     KA40AD3153
# 7       Arrest         True           30+                True     DL75KZ7835
# 8       Arrest        False          0-15                True     DL50PO5101
# 9      Warning         True         16-30               False     KA79RD2271
#
#   stop_time_12hr
# 0       12:00 AM
# 1       12:01 AM
# 2       12:02 AM
# 3       12:03 AM
# 4       12:04 AM
# 5       12:05 AM
# 6       12:06 AM
# 7       12:07 AM
# 8       12:08 AM
# 9       12:09 AM

# %% [markdown]
# ####Data Type conversion

# %%
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  datetime64[ns]
#  1   stop_date_time      65538 non-null  datetime64[ns]
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_race         65538 non-null  object
#  6   violation_raw       65538 non-null  object
#  7   search_conducted    65538 non-null  bool
#  8   search_type         65538 non-null  object
#  9   stop_outcome        65538 non-null  object
#  10  is_arrested         65538 non-null  bool
#  11  stop_duration       65538 non-null  object
#  12  drugs_related_stop  65538 non-null  bool
#  13  vehicle_number      65538 non-null  object
#  14  stop_time_12hr      65538 non-null  object
# dtypes: bool(3), datetime64[ns](2), int64(1), object(9)
# memory usage: 6.2+ MB

# %%
traffic_df['stop_time'] = pd.to_datetime(traffic_df['stop_date']+' '+ traffic_df['stop_time'])

# %%
traffic_df['stop_date']=pd.to_datetime(traffic_df['stop_date'])

# %%
traffic_df.rename(columns={'stop_time': 'stop_date_time'}, inplace=True)

# %%
# convert to 12-hour format
traffic_df['stop_time_12hr'] = traffic_df['stop_date_time'].dt.strftime('%I:%M %p')

# %% [markdown]
# ####Handling Null Values

# %%
traffic_df.isnull().sum()
# Out:
# stop_date                 0
# stop_date_time            0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# stop_time_12hr            0
# dtype: int64

# %%
traffic_df['search_type'].value_counts(dropna=False)
# Out:
# search_type
# Frisk             21971
# Vehicle Search    21847
# NaN               21720
# Name: count, dtype: int64

# %%
traffic_df.head(10)
# Out:
#    stop_date      stop_date_time country_name driver_gender  driver_age_raw  \
# 0 2020-01-01 2020-01-01 00:00:00       Canada             M              59
# 1 2020-01-01 2020-01-01 00:01:00        India             M              35
# 2 2020-01-01 2020-01-01 00:02:00          USA             M              26
# 3 2020-01-01 2020-01-01 00:03:00       Canada             M              26
# 4 2020-01-01 2020-01-01 00:04:00       Canada             M              62
# 5 2020-01-01 2020-01-01 00:05:00       Canada             F              44
# 6 2020-01-01 2020-01-01 00:06:00          USA             F              80
# 7 2020-01-01 2020-01-01 00:07:00        India             M              72
# 8 2020-01-01 2020-01-01 00:08:00          USA             F              80
# 9 2020-01-01 2020-01-01 00:09:00          USA             M              43
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0          19       Asian     Drunk Driving  Speeding              True
# 1          58       Other             Other     Other             False
# 2          76       Black  Signal Violation  Speeding             False
# 3          76       Black          Speeding       DUI              True
# 4          75       Other          Speeding     Other             False
# 5          73       Other     Drunk Driving     Other              True
# 6          70       White  Signal Violation  Speeding             False
# 7          50       Asian     Drunk Driving     Other             False
# 8          30    Hispanic             Other  Seatbelt              True
# 9          21       Asian  Signal Violation    Signal              True
#
#       search_type stop_outcome  is_arrested stop_duration  drugs_related_stop  \
# 0  Vehicle Search       Ticket         True     16-30 Min                True
# 1  Vehicle Search       Arrest         True     16-30 Min                True
# 2           Frisk       Ticket         True     16-30 Min                True
# 3           Frisk      Warning        False      0-15 Min                True
# 4  Vehicle Search       Arrest         True     16-30 Min               False
# 5  Vehicle Search       Ticket        False     16-30 Min               False
# 6  Vehicle Search       Ticket        False       30+ Min               False
# 7             NaN       Arrest         True       30+ Min                True
# 8           Frisk       Arrest        False      0-15 Min                True
# 9             NaN      Warning         True     16-30 Min               False
#
#   vehicle_number stop_time_12hr
# 0     UP76DY3473       12:00 AM
# 1     RJ83PZ4441       12:01 AM
# 2     RJ32OM7264       12:02 AM
# 3     RJ76TI3807       12:03 AM
# 4     WB63BB8305       12:04 AM
# 5     MH89ZF7676       12:05 AM
# 6     KA40AD3153       12:06 AM
# 7     DL75KZ7835       12:07 AM
# 8     DL50PO5101       12:08 AM
# 9     KA79RD2271       12:09 AM

# %%
traffic_df.loc[traffic_df['search_type'].isna(),'search_type']='None' #Replace Nan to None

# %%
traffic_df['country_name'].value_counts()
# Out:
# country_name
# India     21998
# Canada    21908
# USA       21632
# Name: count, dtype: int64

# %%
traffic_df['driver_gender'].value_counts()
# Out:
# driver_gender
# F    32881
# M    32657
# Name: count, dtype: int64

# %%
traffic_df['driver_age_raw'].value_counts()
# Out:
# driver_age_raw
# 75    1134
# 50    1100
# 41    1089
# 40    1083
# 59    1080
#       ...
# 44     987
# 65     986
# 78     986
# 25     981
# 47     980
# Name: count, Length: 63, dtype: int64

# %%
traffic_df['driver_race'].value_counts()
# Out:
# driver_race
# White       13168
# Black       13131
# Other       13122
# Asian       13111
# Hispanic    13006
# Name: count, dtype: int64

# %%
traffic_df['violation_raw'].value_counts()
# Out:
# violation_raw
# Seatbelt            13204
# Speeding            13148
# Signal Violation    13113
# Drunk Driving       13094
# Other               12979
# Name: count, dtype: int64

# %%
traffic_df['violation'].value_counts()
# Out:
# violation
# Other       13194
# Speeding    13150
# Signal      13112
# DUI         13075
# Seatbelt    13007
# Name: count, dtype: int64

# %%
traffic_df['search_conducted'].value_counts()
# Out:
# search_conducted
# False    32837
# True     32701
# Name: count, dtype: int64

# %%
traffic_df['search_type'].value_counts()
# Out:
# search_type
# Frisk             21971
# Vehicle Search    21847
# None              21720
# Name: count, dtype: int64

# %%
traffic_df['stop_outcome'].value_counts()
# Out:
# stop_outcome
# Warning    21966
# Ticket     21838
# Arrest     21734
# Name: count, dtype: int64

# %%
traffic_df['is_arrested'].value_counts()
# Out:
# is_arrested
# True     32846
# False    32692
# Name: count, dtype: int64

# %%
traffic_df['stop_duration'].value_counts()
# Out:
# stop_duration
# 30+ Min      21958
# 0-15 Min     21831
# 16-30 Min    21749
# Name: count, dtype: int64

# %%
traffic_df['drugs_related_stop'].value_counts()
# Out:
# drugs_related_stop
# True     32769
# False    32769
# Name: count, dtype: int64

# %%
traffic_df['vehicle_number'].value_counts()
# Out:
# vehicle_number
# UP89PT2924    1
# UP76DY3473    1
# MH42PF3736    1
# UP10NB3599    1
# GJ34FX6230    1
#              ..
# KA40AD3153    1
# MH89ZF7676    1
# WB63BB8305    1
# RJ76TI3807    1
# RJ32OM7264    1
# Name: count, Length: 65538, dtype: int64

# %% [markdown]
# ####Deleting Unwanted Row

# %%
traffic_df.drop(['driver_age'], axis=1, inplace=True)  # if you only use cleaned age

# %%
traffic_df.drop(['violation'], axis=1, inplace=True)  # if you only use cleaned voilation

# %%
traffic_df.head(10)
# Out:
#    stop_date      stop_date_time country_name driver_gender  driver_age_raw  \
# 0 2020-01-01 2020-01-01 00:00:00       Canada             M              59
# 1 2020-01-01 2020-01-01 00:01:00        India             M              35
# 2 2020-01-01 2020-01-01 00:02:00          USA             M              26
# 3 2020-01-01 2020-01-01 00:03:00       Canada             M              26
# 4 2020-01-01 2020-01-01 00:04:00       Canada             M              62
# 5 2020-01-01 2020-01-01 00:05:00       Canada             F              44
# 6 2020-01-01 2020-01-01 00:06:00          USA             F              80
# 7 2020-01-01 2020-01-01 00:07:00        India             M              72
# 8 2020-01-01 2020-01-01 00:08:00          USA             F              80
# 9 2020-01-01 2020-01-01 00:09:00          USA             M              43
#
#   driver_race     violation_raw  search_conducted     search_type  \
# 0       Asian     Drunk Driving              True  Vehicle Search
# 1       Other             Other             False  Vehicle Search
# 2       Black  Signal Violation             False           Frisk
# 3       Black          Speeding              True           Frisk
# 4       Other          Speeding             False  Vehicle Search
# 5       Other     Drunk Driving              True  Vehicle Search
# 6       White  Signal Violation             False  Vehicle Search
# 7       Asian     Drunk Driving             False            None
# 8    Hispanic             Other              True           Frisk
# 9       Asian  Signal Violation              True            None
#
#   stop_outcome  is_arrested stop_duration  drugs_related_stop vehicle_number  \
# 0       Ticket         True     16-30 Min                True     UP76DY3473
# 1       Arrest         True     16-30 Min                True     RJ83PZ4441
# 2       Ticket         True     16-30 Min                True     RJ32OM7264
# 3      Warning        False      0-15 Min                True     RJ76TI3807
# 4       Arrest         True     16-30 Min               False     WB63BB8305
# 5       Ticket        False     16-30 Min               False     MH89ZF7676
# 6       Ticket        False       30+ Min               False     KA40AD3153
# 7       Arrest         True       30+ Min                True     DL75KZ7835
# 8       Arrest        False      0-15 Min                True     DL50PO5101
# 9      Warning         True     16-30 Min               False     KA79RD2271
#
#   stop_time_12hr
# 0       12:00 AM
# 1       12:01 AM
# 2       12:02 AM
# 3       12:03 AM
# 4       12:04 AM
# 5       12:05 AM
# 6       12:06 AM
# 7       12:07 AM
# 8       12:08 AM
# 9       12:09 AM

# %%
traffic_df['stop_duration']=traffic_df['stop_duration'].str.split(' ').str[0] #slicing 'min' from "stop_duration"

# %% [markdown]
# ####Deleting Duplicate Values

# %%
traffic_df.drop_duplicates(inplace=True) #Used to drop the duplicate values

# %%
traffic_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ####Storing cleaned data to CSV

# %%
traffic_df.to_csv('cleaned_traffic_stop_new.csv', index=False)

# %% [markdown]
# ####Storing Cleaned Data to SQL

# %%
db_url = "postgresql+psycopg2://username:password@localhost:5432/db_name" #Database Connection, Host Name, Password, Database Name

# %%
from sqlalchemy import create_engine, inspect
engine=create_engine(db_url) # Importing necessary packages from pandas

# %%
traffic_df.to_sql('traffic_stop',engine,index=False,if_exists='replace') # Creating New Table and storing the cleaned data into SQL
# Out:
# 538

# %%
query = """SELECT * FROM traffic_stop"""

slect_fulltable_df = pd.read_sql(query,engine)
slect_fulltable_df
# Out:
#        stop_date           stop_time country_name driver_gender  \
# 0     2020-01-01 1900-01-01 00:00:00       Canada             M
# 1     2020-01-01 1900-01-01 00:01:00        India             M
# 2     2020-01-01 1900-01-01 00:02:00          USA             M
# 3     2020-01-01 1900-01-01 00:03:00       Canada             M
# 4     2020-01-01 1900-01-01 00:04:00       Canada             M
# ...          ...                 ...          ...           ...
# 65533 2020-02-15 1900-01-01 12:13:00        India             F
# 65534 2020-02-15 1900-01-01 12:14:00       Canada             F
# 65535 2020-02-15 1900-01-01 12:15:00          USA             M
# 65536 2020-02-15 1900-01-01 12:16:00       Canada             F
# 65537 2020-02-15 1900-01-01 12:17:00          USA             F
#
#        driver_age_raw driver_race     violation_raw violation  \
# 0                  59       Asian     Drunk Driving  Speeding
# 1                  35       Other             Other     Other
# 2                  26       Black  Signal Violation  Speeding
# 3                  26       Black          Speeding       DUI
# 4                  62       Other          Speeding     Other
# ...               ...         ...               ...       ...
# 65533              54       Black             Other     Other
# 65534              18    Hispanic          Seatbelt     Other
# 65535              27       Asian          Seatbelt       DUI
# 65536              49       Black          Seatbelt     Other
# 65537              72       Other          Seatbelt  Speeding
#
#        search_conducted     search_type stop_outcome  is_arrested  \
# 0                  True  Vehicle Search       Ticket         True
# 1                 False  Vehicle Search       Arrest         True
# 2                 False           Frisk       Ticket         True
# 3                  True           Frisk      Warning        False
# 4                 False  Vehicle Search       Arrest         True
# ...                 ...             ...          ...          ...
# 65533             False  Vehicle Search       Arrest         True
# 65534              True  Vehicle Search       Ticket        False
# 65535              True           Frisk       Ticket         True
# 65536             False            None      Warning         True
# 65537              True            None       Ticket         True
#
#       stop_duration  drugs_related_stop vehicle_number
# 0             16-30                True     UP76DY3473
# 1             16-30                True     RJ83PZ4441
# 2             16-30                True     RJ32OM7264
# 3              0-15                True     RJ76TI3807
# 4             16-30               False     WB63BB8305
# ...             ...                 ...            ...
# 65533         16-30               False     DL56GW6568
# 65534         16-30                True     TN73EO7098
# 65535           30+                True     GJ33MX8328
# 65536          0-15                True     KA24UZ8488
# 65537         16-30               False     UP89PT2924
#
# [65538 rows x 15 columns]

# %% [markdown]
# ####SQL queries(Medium level):

# %%
#  1.What are the top 10 vehicle_Number involved in drug-related stops?
query = """
SELECT vehicle_number,COUNT(drugs_related_stop) AS drug_related_stop_count
FROM traffic_stop WHERE drugs_related_stop=TRUE
GROUP BY vehicle_number
ORDER BY drug_related_stop_count DESC LIMIT 10;
"""

query_1_df = pd.read_sql(query,engine)
query_1_df
# Out:
#   vehicle_number  drug_related_stop_count
# 0     GJ99TA8565                        1
# 1     MH85NR6252                        1
# 2     RJ88QF9639                        1
# 3     WB82DO3310                        1
# 4     TN98SO9644                        1
# 5     RJ69QZ5424                        1
# 6     RJ79BO9666                        1
# 7     TN57CN7350                        1
# 8     TN72KS4261                        1
# 9     TN16EN4769                        1

# %%
# 2.Which vehicles were most frequently searched?
query = """SELECT violation_raw, COUNT(violation_raw) AS search_count FROM traffic_stop WHERE search_conducted='TRUE' GROUP BY violation_raw ORDER BY search_count DESC LIMIT 10;"""

query_2_df = pd.read_sql(query,engine)
query_2_df
# Out:
#       violation_raw  search_count
# 0  Signal Violation          6623
# 1          Speeding          6587
# 2     Drunk Driving          6532
# 3          Seatbelt          6531
# 4             Other          6428

# %%
# 4.Which driver age group had the highest arrest rate?
query = """SELECT driver_age_raw, COUNT(is_arrested) AS arrest_count FROM traffic_stop WHERE is_arrested= TRUE GROUP BY driver_age_raw ORDER BY arrest_count DESC LIMIT 10;"""

query_4_df = pd.read_sql(query,engine)
query_4_df
# Out:
#    driver_age_raw  arrest_count
# 0              75           590
# 1              56           567
# 2              74           566
# 3              70           561
# 4              23           552
# 5              59           552
# 6              40           551
# 7              32           549
# 8              34           548
# 9              46           544

# %%
# 5.What is the gender distribution of drivers stopped in each country?
query = """SELECT country_name,driver_gender,COUNT(driver_gender) AS gender_count FROM traffic_stop GROUP BY country_name,driver_gender ORDER BY country_name,gender_count DESC;"""

query_5_df = pd.read_sql(query,engine)
query_5_df
# Out:
#   country_name driver_gender  gender_count
# 0       Canada             F         10997
# 1       Canada             M         10911
# 2        India             F         11043
# 3        India             M         10955
# 4          USA             F         10841
# 5          USA             M         10791

# %%
# 6.Which race and gender combination has the highest search rate?
query = """SELECT driver_race,driver_gender,COUNT(search_conducted) AS search_count FROM traffic_stop WHERE search_conducted=TRUE GROUP BY driver_race,driver_gender ORDER BY search_count DESC LIMIT 10;"""

query_6_df = pd.read_sql(query,engine)
query_6_df
# Out:
#   driver_race driver_gender  search_count
# 0       Asian             F          3410
# 1    Hispanic             F          3326
# 2       Other             F          3294
# 3       Black             M          3265
# 4       White             M          3262
# 5       White             F          3257
# 6       Asian             M          3239
# 7       Other             M          3238
# 8    Hispanic             M          3212
# 9       Black             F          3198

# %%
# 7.What time of day sees the most traffic stops?
query = """SELECT EXTRACT(HOUR FROM stop_date_time) AS hour_of_day, COUNT(*) AS stop_count
FROM traffic_stop
GROUP BY hour_of_day
ORDER BY stop_count DESC
LIMIT 10;"""

#DOUBT

#"""SELECT EXTRACT(HOUR FROM stop_time) AS hour_of_day, COUNT(hour_of_day) AS stop_count FROM traffic_stop GROUP BY hour_of_day ORDER BY stop_count DESC LIMIT 10;"""

query_7_df = pd.read_sql(query,engine)
query_7_df
# Out:
#    hour_of_day  stop_count
# 0          6.0        2760
# 1         10.0        2760
# 2          4.0        2760
# 3          9.0        2760
# 4          2.0        2760
# 5          3.0        2760
# 6          0.0        2760
# 7          7.0        2760
# 8         11.0        2760
# 9          1.0        2760

# %%
traffic_df['stop_duration'].value_counts()
# Out:
# stop_duration
# 30+      21958
# 0-15     21831
# 16-30    21749
# Name: count, dtype: int64

# %%
# 8.What is the average stop duration for different violations?
query = """SELECT violation,
       ROUND(AVG(CASE stop_duration
               WHEN '0-15' THEN 7.5
               WHEN '16-30' THEN 23
               WHEN '30+' THEN 35
           END),2) AS avg_stop_duration
FROM traffic_stop
GROUP BY violation
ORDER BY avg_stop_duration DESC;"""

query_8_df = pd.read_sql(query,engine)
query_8_df
# Out:
#   violation  avg_stop_duration
# 0     Other              22.20
# 1  Seatbelt              21.83
# 2  Speeding              21.79
# 3       DUI              21.74
# 4    Signal              21.71

# %%
# 9.Are stops during the night more likely to lead to arrests?
query = """SELECT EXTRACT(HOUR FROM stop_date_time) AS hour_of_day, COUNT(is_arrested) AS arrest_count
FROM traffic_stop
WHERE is_arrested = TRUE
GROUP BY hour_of_day
ORDER BY arrest_count DESC
LIMIT 10;"""

query_9_df = pd.read_sql(query,engine)
query_9_df
# Out:
#    hour_of_day  arrest_count
# 0          8.0          1426
# 1          7.0          1415
# 2         11.0          1414
# 3          6.0          1410
# 4         10.0          1403
# 5         18.0          1377
# 6          9.0          1375
# 7         14.0          1374
# 8         22.0          1372
# 9         17.0          1372

# %%
# 10.Which violations are most associated with searches or arrests?
query = """
SELECT
  violation,
  COUNT(*) AS total_stops_with_search_and_arrest
FROM traffic_stop
WHERE search_conducted = TRUE AND is_arrested = TRUE
GROUP BY violation
ORDER BY total_stops_with_search_and_arrest DESC;
"""

query_10_df = pd.read_sql(query,engine)
query_10_df
# Out:
#   violation  total_stops_with_search_and_arrest
# 0  Seatbelt                                3361
# 1  Speeding                                3303
# 2    Signal                                3285
# 3     Other                                3235
# 4       DUI                                3224

# %%
# 11.Which violations are most common among younger drivers (<25)?
query = """
SELECT violation,
COUNT(violation) AS violation_count
FROM traffic_stop
WHERE driver_age_raw<25
GROUP BY violation
ORDER BY violation_count DESC;
"""

query_11_df = pd.read_sql(query,engine)
query_11_df
# Out:
#   violation  violation_count
# 0  Speeding             1526
# 1    Signal             1448
# 2  Seatbelt             1430
# 3     Other             1424
# 4       DUI             1367

# %%
# 12.Is there a violation that rarely results in search or arrest?
query = """
SELECT
  violation,
  COUNT(*) AS total_stops_without_search_or_arrest
FROM traffic_stop
WHERE search_conducted = FALSE AND is_arrested = FALSE
GROUP BY violation
ORDER BY total_stops_without_search_or_arrest ASC;
"""

query_12_df = pd.read_sql(query,engine)
query_12_df
# Out:
#   violation  total_stops_without_search_or_arrest
# 0       DUI                                  3208
# 1  Seatbelt                                  3233
# 2  Speeding                                  3282
# 3     Other                                  3337
# 4    Signal                                  3339

# %%
# 13.Which countries report the highest rate of drug-related stops?
query = """
SELECT
  country_name,
  COUNT(drugs_related_stop) AS drug_related_stop_count
FROM traffic_stop
WHERE drugs_related_stop = TRUE
GROUP BY country_name
ORDER BY drug_related_stop_count DESC LIMIT 1;
"""

query_13_df = pd.read_sql(query,engine)
query_13_df
# Out:
#   country_name  drug_related_stop_count
# 0       Canada                    10976

# %%
# 14.What is the arrest rate by country and violation?
query = """
SELECT
  country_name,
  violation,
  ROUND(AVG(CASE WHEN is_arrested = TRUE THEN 1.0 ELSE 0 END) * 100, 2)AS arrest_rate
FROM traffic_stop
GROUP BY country_name, violation
ORDER BY arrest_rate DESC;

"""

query_14_df = pd.read_sql(query,engine)
query_14_df
# Out:
#    country_name violation  arrest_rate
# 0        Canada       DUI        51.13
# 1         India       DUI        50.84
# 2         India  Speeding        50.76
# 3         India    Signal        50.65
# 4           USA  Seatbelt        50.58
# 5         India  Seatbelt        50.56
# 6        Canada  Seatbelt        50.46
# 7        Canada     Other        50.29
# 8           USA    Signal        49.99
# 9        Canada  Speeding        49.94
# 10          USA  Speeding        49.83
# 11          USA       DUI        49.66
# 12        India     Other        49.29
# 13       Canada    Signal        49.18
# 14          USA     Other        48.59

# %%
# 15.Which country has the most stops with search conducted?
query = """
SELECT
  country_name,
  COUNT(search_conducted) AS search_count
FROM traffic_stop
WHERE search_conducted = TRUE
GROUP BY country_name
ORDER BY search_count DESC LIMIT 1;
"""

query_15_df = pd.read_sql(query,engine)
query_15_df
# Out:
#   country_name  search_count
# 0       Canada         11020

# %% [markdown]
# ####SQL queries(Complex):

# %%
#1.Yearly Breakdown of Stops and Arrests by Country (Using Subquery and Window Functions)
query = """
WITH yearly_summary AS
	(SELECT
		country_name,
		EXTRACT(YEAR FROM stop_date) AS year,
		COUNT(is_arrested) AS total_stops,
		SUM(CASE WHEN is_arrested = TRUE THEN 1 ELSE 0 END) AS arrest_count
		FROM traffic_stop
		GROUP BY country_name, EXTRACT(YEAR FROM stop_date))
SELECT country_name,year,total_stops,arrest_count,SUM(arrest_count) OVER (PARTITION BY country_name ORDER BY year) AS cumulative_arrest_count FROM yearly_summary;"""

query_c1_df = pd.read_sql(query,engine)
query_c1_df
# Out:
#   country_name    year  total_stops  arrest_count  cumulative_arrest_count
# 0       Canada  2020.0        21908         10999                  10999.0
# 1        India  2020.0        21998         11091                  11091.0
# 2          USA  2020.0        21632         10756                  10756.0

# %%
#2.Driver Violation Trends Based on Age and Race (Join with Subquery)
query="""
SELECT ts.driver_age_raw, ts.driver_race, COUNT(*) AS count_race
FROM (
    SELECT driver_age_raw, driver_race
    FROM traffic_stop
    WHERE driver_age_raw IS NOT NULL AND driver_race IS NOT NULL
) AS ts
GROUP BY ts.driver_age_raw, ts.driver_race
ORDER BY ts.driver_age_raw, count_race;
"""

query_c2_df = pd.read_sql(query,engine)
query_c2_df
# Out:
#      driver_age_raw driver_race  count_race
# 0                18       Black         186
# 1                18       White         187
# 2                18       Asian         200
# 3                18       Other         211
# 4                18    Hispanic         212
# ..              ...         ...         ...
# 310              80       White         197
# 311              80       Asian         199
# 312              80       Black         202
# 313              80       Other         207
# 314              80    Hispanic         226
#
# [315 rows x 3 columns]

# %%
#3.Time Period Analysis of Stops (Joining with Date Functions) , Number of Stops by Year,Month, Hour of the Day
#Cast method is used the slice the decimal value
query = """
SELECT
    CAST(EXTRACT(YEAR FROM stop_date) AS INT) AS stop_year,
    CAST(EXTRACT(MONTH FROM stop_date) AS INT) AS stop_month,
    CAST(EXTRACT(HOUR FROM stop_date_time) AS INT) AS stop_hour,
    COUNT(*) AS total_stops
FROM traffic_stop
GROUP BY stop_year, stop_month, stop_hour
ORDER BY stop_year, stop_month, stop_hour;
"""

query_c3_df = pd.read_sql(query,engine)
query_c3_df
# Out:
#    stop_year  stop_month  stop_hour  total_stops
# 0       2020           1          0         1860
# 1       2020           1          1         1860
# 2       2020           1          2         1860
# 3       2020           1          3         1860
# 4       2020           1          4         1860
# 5       2020           1          5         1860
# 6       2020           1          6         1860
# 7       2020           1          7         1860
# 8       2020           1          8         1860
# 9       2020           1          9         1860

# %%
#4.Violations with High Search and Arrest Rates (Window Function)
query = """
SELECT
    violation_raw,
    COUNT(violation_raw) AS total_violation_raw_count,
    SUM(CASE WHEN search_conducted = TRUE THEN 1 ELSE 0 END) AS search_count,
    SUM(CASE WHEN is_arrested = TRUE THEN 1 ELSE 0 END) AS arrest_count,
    ROUND(AVG(CASE WHEN search_conducted = TRUE THEN 1.0 ELSE 0 END) * 100, 2) AS search_avg_rate,
    ROUND(AVG(CASE WHEN is_arrested = TRUE THEN 1.0 ELSE 0 END) * 100, 2) AS arrest_avg_rate
FROM traffic_stop
GROUP BY violation_raw
ORDER BY search_count DESC, arrest_count DESC, search_avg_rate DESC, arrest_avg_rate DESC;
"""

query_c4_df = pd.read_sql(query,engine)
query_c4_df
# Out:
#       violation_raw  total_violation_raw_count  search_count  arrest_count  \
# 0  Signal Violation                      13113          6623          6574
# 1          Speeding                      13148          6587          6500
# 2     Drunk Driving                      13094          6532          6625
# 3          Seatbelt                      13204          6531          6689
# 4             Other                      12979          6428          6458
#
#    search_avg_rate  arrest_avg_rate
# 0            50.51            50.13
# 1            50.10            49.44
# 2            49.89            50.60
# 3            49.46            50.66
# 4            49.53            49.76

# %%
#5.Driver Demographics by Country (Age, Gender, and Race)
query = """
SELECT
    country_name,
    ROUND(AVG(driver_age_raw), 1) AS avg_age,
    COUNT(*) AS total_stops,
    SUM(CASE WHEN driver_gender = 'M' THEN 1 ELSE 0 END) AS male_count,
    SUM(CASE WHEN driver_gender = 'F' THEN 1 ELSE 0 END) AS female_count,
    SUM(CASE WHEN driver_race = 'White' THEN 1 ELSE 0 END) AS white_count,
    SUM(CASE WHEN driver_race = 'Black' THEN 1 ELSE 0 END) AS black_count,
    SUM(CASE WHEN driver_race = 'Hispanic' THEN 1 ELSE 0 END) AS hispanic_count,
    SUM(CASE WHEN driver_race = 'Asian' THEN 1 ELSE 0 END) AS asian_count,
    SUM(CASE WHEN driver_race = 'Other' THEN 1 ELSE 0 END) AS other_race_count
FROM traffic_stop
GROUP BY country_name
ORDER BY total_stops DESC;

"""

query_c5_df = pd.read_sql(query,engine)
query_c5_df
# Out:
#   country_name  avg_age  total_stops  male_count  female_count  white_count  \
# 0        India     49.0        21998       10955         11043         4346
# 1       Canada     49.1        21908       10911         10997         4429
# 2          USA     49.0        21632       10791         10841         4393
#
#    black_count  hispanic_count  asian_count  other_race_count
# 0         4418            4406         4451              4377
# 1         4342            4395         4344              4398
# 2         4371            4205         4316              4347

# %%
#6.Top 5 Violations with Highest Arrest Rates
query = """
SELECT
  violation_raw,
  COUNT(is_arrested) AS total_stops,
  SUM(CASE WHEN is_arrested = TRUE THEN 1 ELSE 0 END) AS arrest_count,
  ROUND(AVG(CASE WHEN is_arrested = TRUE THEN 1.0 ELSE 0 END) * 100, 2) AS arrest_avg_rate
FROM traffic_stop
GROUP BY violation_raw
ORDER BY arrest_avg_rate DESC
LIMIT 5;
"""

query_c6_df = pd.read_sql(query,engine)
query_c6_df
# Out:
#       violation_raw  total_stops  arrest_count  arrest_avg_rate
# 0          Seatbelt        13204          6689            50.66
# 1     Drunk Driving        13094          6625            50.60
# 2  Signal Violation        13113          6574            50.13
# 3             Other        12979          6458            49.76
# 4          Speeding        13148          6500            49.44
